# %% [markdown]
# # Exploración Dataset Bank Account Fraud Dataset Suite
#
# Se explora el dataset propuesto por Feedsai publicado a través de NeurIPS2022, el cual presenta 6 datasets sintéticos de fraude bancario.

# %% [markdown]
# ## Importación librerías

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# Se establece la opción para que al momento de observar el dataset muestre todas las columnas.
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Importación datasets

# %%
# Se importa el dataset "base" y se observa una muestra de 5 datos para revisar que haya cargado correctamente.
data_base = pd.read_csv("../../Data/Bank Fraud/Base.csv")

data_base.sample(5)
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 757105           0     0.9               0.132858                         -1
# 391004           0     0.4               0.674254                         92
# 395784           0     0.4               0.264724                         -1
# 834542           0     0.9               0.152323                         -1
# 405686           0     0.2               0.886482                         -1
#
#         current_address_months_count  customer_age  days_since_request  \
# 757105                            42            60            0.040511
# 391004                            10            20           13.634347
# 395784                           260            20            0.032369
# 834542                            33            40            0.035614
# 405686                           180            60            0.005670
#
#         intended_balcon_amount payment_type  zip_count_4w  velocity_6h  \
# ...

# %%
# Se importa el dataset "Variant I" y se observa una muestra de 5 datos para revisar que haya cargado correctamente.
data_b1 = pd.read_csv("../../Data/Bank Fraud/Variant I.csv")

data_b1.sample(5)
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 316865           0     0.1               0.171567                         -1
# 900029           0     0.4               0.769695                         -1
# 443245           0     0.1               0.510169                         -1
# 574735           0     0.7               0.894194                         -1
# 894016           0     0.2               0.839183                         -1
#
#         current_address_months_count  customer_age  days_since_request  \
# 316865                           101            60            0.909387
# 900029                           134            40            0.018435
# 443245                           187            20            0.034710
# 574735                           198            30            0.017333
# 894016                           196            40            0.002603
#
#         intended_balcon_amount payment_type  zip_count_4w  velocity_6h  \
# ...

# %%
# Se importa el dataset "Variant II" y se observa una muestra de 5 datos para revisar que haya cargado correctamente.
data_b2 = pd.read_csv("../../Data/Bank Fraud/Variant II.csv")

data_b2.sample(5)
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 472072           0     0.9               0.090023                         -1
# 357205           0     0.9               0.162858                         -1
# 994049           0     0.5               0.564787                         45
# 322586           0     0.2               0.892197                         -1
# 516519           0     0.7               0.272861                          9
#
#         current_address_months_count  customer_age  days_since_request  \
# 472072                            40            50            0.008326
# 357205                           184            50            0.933517
# 994049                             5            30            0.026038
# 322586                            81            30            0.018758
# 516519                             1            20            0.007581
#
#         intended_balcon_amount payment_type  zip_count_4w  velocity_6h  \
# ...

# %%
# Se importa el dataset "Variant III" y se observa una muestra de 5 datos para revisar que haya cargado correctamente.
data_b3 = pd.read_csv("../../Data/Bank Fraud/Variant III.csv")

data_b3.sample(5)
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 623680           0     0.4               0.596897                         -1
# 3511             0     0.1               0.929897                         -1
# 746595           0     0.1               0.758617                         -1
# 953640           0     0.7               0.387695                         -1
# 98272            0     0.2               0.058691                         -1
#
#         current_address_months_count  customer_age  days_since_request  \
# 623680                           110            60            0.021577
# 3511                             124            20            0.001450
# 746595                            64            50            0.012363
# 953640                           161            70            0.024826
# 98272                             41            60            2.805734
#
#         intended_balcon_amount payment_type  zip_count_4w  velocity_6h  \
# ...

# %%
# Se importa el dataset "Variant IV" y se observa una muestra de 5 datos para revisar que haya cargado correctamente.
data_b4 = pd.read_csv("../../Data/Bank Fraud/Variant IV.csv")

data_b4.sample(5)
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 24894            0     0.4               0.826247                         -1
# 436563           0     0.9               0.900613                         -1
# 149753           0     0.4               0.214084                         -1
# 291195           0     0.1               0.995494                         -1
# 454175           0     0.9               0.198270                         28
#
#         current_address_months_count  customer_age  days_since_request  \
# 24894                             58            20            0.010321
# 436563                            43            30            0.026074
# 149753                            21            50            0.015819
# 291195                            74            50            2.590862
# 454175                             1            20            0.013770
#
#         intended_balcon_amount payment_type  zip_count_4w   velocity_6h  \
# ...

# %%
# Se importa el dataset "Variant V" y se observa una muestra de 5 datos para revisar que haya cargado correctamente.
data_b5 = pd.read_csv("../../Data/Bank Fraud/Variant V.csv")

data_b5.sample(5)
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 206273           0     0.7               0.024247                         13
# 732226           0     0.3               0.182732                         -1
# 73430            0     0.8               0.753310                         -1
# 639047           0     0.6               0.083785                         -1
# 978393           0     0.6               0.522864                         -1
#
#         current_address_months_count  customer_age  days_since_request  \
# 206273                             8            50           22.851970
# 732226                           377            60            0.007381
# 73430                            195            50            0.004586
# 639047                            42            30            0.005947
# 978393                            37            10            0.024722
#
#         intended_balcon_amount payment_type  zip_count_4w  velocity_6h  \
# ...

# %% [markdown]
# ## Exploración del dataset

# %% [markdown]
# ### Dataset base

# %%
# Se observa la información del dataset.
data_base.info()

# No se observan datos nulos.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
# ...

# %%
# Se revisan si existen filas duplicadas.
duplicados = data_base.duplicated()
print(data_base[duplicados])

# En este caso no se observan que existan filas de hechos duplicados.
# Out:
# Empty DataFrame
# Columns: [fraud_bool, income, name_email_similarity, prev_address_months_count, current_address_months_count, customer_age, days_since_request, intended_balcon_amount, payment_type, zip_count_4w, velocity_6h, velocity_24h, velocity_4w, bank_branch_count_8w, date_of_birth_distinct_emails_4w, employment_status, credit_risk_score, email_is_free, housing_status, phone_home_valid, phone_mobile_valid, bank_months_count, has_other_cards, proposed_credit_limit, foreign_request, source, session_length_in_minutes, device_os, keep_alive_session, device_distinct_emails_8w, device_fraud_count, month]
# Index: []

# %%
# Se describe la composición de las variables numéricas del dataset

print(data_base.describe())
# Out:
#            fraud_bool          income  name_email_similarity  \
# count  1000000.000000  1000000.000000         1000000.000000
# mean         0.011029        0.562696               0.493694
# std          0.104438        0.290343               0.289125
# min          0.000000        0.100000               0.000001
# 25%          0.000000        0.300000               0.225216
# 50%          0.000000        0.600000               0.492153
# 75%          0.000000        0.800000               0.755567
# max          1.000000        0.900000               0.999999
#
#        prev_address_months_count  current_address_months_count  \
# count             1000000.000000                1000000.000000
# mean                   16.718568                     86.587867
# std                    44.046230                     88.406599
# min                    -1.000000                     -1.000000
# 25%                    -1.000000                     19.000000
# ...

# %% [markdown]
# A partir de la visualización de la composición de las variables numéricas del dataset, se sugieren los siguientes posibles cambios o aspectos a tener en cuenta, al momento del entrenamiento del modelo de Machine Learning y la construcción de la visualización de los datos en el dashboard:
#  1. Se sugiere eliminar la columna "month" (mes), ya que no representa datos sobre el intento de fraude en sí, sino sólo el momento en el que se hizo la solicitud dentro del periodo de tiempo en el que se tomaron los datos.
#  2. Se sugiere cambiar los valores negativos [-Infinito,-1] de la/s columna/s "prev_address_months_count", "current_address_months_count", "intended_balcon_amount", "bank_months_count", "session_length_in_minutes", "device_distinct_emails_8w" a nulo o 0, ya que no representa un valor numérico, sino la ausencia del dato.
#  3. Se sugiere revisar la especificidad de las siguientes columnas: "zip_count_4w", "velocity_6h", "velocity_24h", "velocity_4w", "bank_branch_count_8w", "date_of_birth_distinct_emails_4w" y su utilidad para el modelo de ML.
#  4. En las columnas "credit_risk_score", "income" se podría agrupar los valores en categorías tales como "alto", "medio", "bajo", con el propósito de ser visualizado con mayor facilidad.
#  5. Si bien las columnas "email_is_free", "phone_home_valid", "phone_mobile_valid", "has_other_cards", "foreign_request", "keep_alive_session", "device_fraud_count" son numéricas, representan datos binarios, por lo que su interpretación debe estar ligada a dicha cualidad.

# %%
# Se revisan outliers para las variables numéricas. 

numericas = ["prev_address_months_count", "current_address_months_count", "intended_balcon_amount", "bank_months_count",
    "session_length_in_minutes", "device_distinct_emails_8w", "zip_count_4w", "velocity_6h", 
    "velocity_24h", "velocity_4w", "bank_branch_count_8w", "date_of_birth_distinct_emails_4w",
    "credit_risk_score", "income"
]


for element in numericas: 
    print(f"Proceso para {element}")
    # Se calcula el Q1 (Primer cuartil) y Q3 (Tercer cuartil).
    Q1 = data_base[element].quantile(0.25)
    Q3 = data_base[element].quantile(0.75)

    print(f"El primer cuartil para {element} es {Q1}")
    print(f"El tercer cuartil para {element} es {Q3}")

    # Se hace el cálculo del IQR (Rango Intercuartil).
    IQR = Q3 - Q1
    print(f"El rango intercuartil para {element} es {IQR}")

    # Se establecen los límites para encontrar a los outliers.
    inferior = Q1 - 1.5 * IQR
    superior = Q3 + 1.5 * IQR

    # Filtrado de outliers
    outliers = data_base[
        (data_base[element] < inferior) | (data_base[element] > superior)
    ]

    # Se observan los casos de outliers
    print(f"Se identificaron {outliers.shape[0]} outliers para {element}")
    print(outliers.head)
# Out:
# Proceso para prev_address_months_count
# El primer cuartil para prev_address_months_count es -1.0
# El tercer cuartil para prev_address_months_count es 12.0
# El rango intercuartil para prev_address_months_count es 13.0
# Se identificaron 157320 outliers para prev_address_months_count
# <bound method NDFrame.head of         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 26               0     0.4               0.043498                         33
# 37               0     0.6               0.772867                         96
# 39               0     0.6               0.030694                         48
# 40               0     0.9               0.160079                         49
# 41               0     0.4               0.523423                         51
# ...            ...     ...                    ...                        ...
# 999971           0     0.1               0.404750                         52
# ...

# %% [markdown]
# A continuación se presenta el número de outliers identificados para cada una de las variables exploradas:
# - "prev_address_months_count", 157,320 outliers identificados.
# - "current_address_months_count", 41,001 outliers identificados.
# - "intended_balcon_amount", 222,702 outliers identificados.
# - "bank_months_count", 0 outliers identificados.
# - "session_length_in_minutes", 78,789 outliers identificados.
# - "device_distinct_emails_8w", 31,933 outliers identificados.
# - "zip_count_4w", 59,871 outliers identificados.
# - "velocity_6h", 9,005 outliers identificados.
# - "velocity_24h", 2,917 outliers identificados.
# - "velocity_4w", 0 outliers identificados.
# - "bank_branch_count_8w", 175,243 outliers identificados.
# - "date_of_birth_distinct_emails_4w", 9,734 outliers identificados.
# - "credit_risk_score", 8,729 outliers identificados.
# - "income", 0 outliers identificados.

# %%
# Se describe la composición de las variables categóricas del dataset. 

categóricas = ["payment_type" # tipo de pago
     ,"customer_age" # edad del cliente
     ,"employment_status"# estado de empleabilidad
     ,"housing_status" # estado de vivienda actual
     ,"has_other_cards" # ¿tiene otras tarjetas?
     ,"source" # origen de la transacción
     ,"device_os" # tipo de sistema operativo
     ,"fraud_bool" # Aplicación fraudulenta
     ]

for element in categóricas: 
    print(element)
    print(data_base[element].value_counts(normalize=True))
# Out:
# payment_type
# payment_type
# AB    0.370554
# AA    0.258249
# AC    0.252071
# AD    0.118837
# AE    0.000289
# Name: proportion, dtype: float64
# customer_age
# customer_age
# 30    0.311433
# 20    0.245855
# 40    0.238712
# 50    0.140353
# 60    0.034770
# 10    0.020987
# 70    0.006517
# 80    0.001297
# 90    0.000076
# Name: proportion, dtype: float64
# employment_status
# employment_status
# CA    0.730252
# CB    0.138288
# CF    0.044034
# CC    0.037758
# CD    0.026522
# CE    0.022693
# CG    0.000453
# Name: proportion, dtype: float64
# housing_status
# housing_status
# BC    0.372143
# BB    0.260965
# BA    0.169675
# BE    0.169135
# BD    0.026161
# BF    0.001669
# BG    0.000252
# Name: proportion, dtype: float64
# has_other_cards
# has_other_cards
# 0    0.777012
# 1    0.222988
# Name: proportion, dtype: float64
# source
# source
# INTERNET    0.992952
# TELEAPP     0.007048
# Name: proportion, dtype: float64
# device_os
# device_os
# other        0.342728
# ...

# %% [markdown]
# A continuación se grafica la composición de las variables categóricas:

# %%
# Entradas por método de pago.

sns.histplot(data_base,x = "payment_type")
plt.xlabel("Tipo de pago")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de pago")
plt.show()

# Entradas por rango etario.

sns.histplot(data_base,x = "customer_age")
plt.xlabel("Rango etario")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por rango etario")
plt.show()

# Entradas por estado de empleabilidad.

sns.histplot(data_base,x = "employment_status")
plt.xlabel("Estado empleabilidad")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de empleabilidad")
plt.show()

# Entradas por estado de vivienda.

sns.histplot(data_base,x = "housing_status")
plt.xlabel("Estado de vivienda")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de vivienda")
plt.show()

# Entradas por posesión de tarjetas.

data_counts = data_base['has_other_cards'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por posesión de tarjetas")
plt.show()

# Entradas por origen de la transacción.

sns.histplot(data_base,x = "source")
plt.xlabel("Origen")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por origen")
plt.show()

# Entradas por tipo de sistema operativo.

sns.histplot(data_base,x = "device_os")
plt.xlabel("Tipo de sistema operativo")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de sistema operativo")
plt.show()

# Entradas por determinación de Aplicación fraudulenta.

data_counts = data_base['fraud_bool'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por determinación de Aplicación fraudulenta")
plt.show()

# %% [markdown]
# A continuación se hace una exploración similar de composición para los demás datasets, no se profundiza en cada uno, ya que las transformaciones a tener en cuenta se realizarán a partir de la muestra del dataset base.

# %% [markdown]
# ### Dataset 1

# %%
# Se observa la información del dataset.
print("Información del dataset")
print(data_b1.info())

print("\n\n")

# Se revisan si existen filas duplicadas.
duplicados = data_b1.duplicated()
print("Duplicados")
print(data_b1[duplicados])

# Se describe la composición de las variables numéricas del dataset
print("\n\n")
print("Composición variables numéricas")
print(data_b1.describe())

# Se revisan outliers para las variables numéricas. 

numericas = ["prev_address_months_count", "current_address_months_count", "intended_balcon_amount", "bank_months_count",
    "session_length_in_minutes", "device_distinct_emails_8w", "zip_count_4w", "velocity_6h", 
    "velocity_24h", "velocity_4w", "bank_branch_count_8w", "date_of_birth_distinct_emails_4w",
    "credit_risk_score", "income"
]

print("\n\n")
print("Outliers")
for element in numericas: 
    print(f"Proceso para {element}")
    # Se calcula el Q1 (Primer cuartil) y Q3 (Tercer cuartil).
    Q1 = data_b1[element].quantile(0.25)
    Q3 = data_b1[element].quantile(0.75)

    print(f"El primer cuartil para {element} es {Q1}")
    print(f"El tercer cuartil para {element} es {Q3}")

    # Se hace el cálculo del IQR (Rango Intercuartil).
    IQR = Q3 - Q1
    print(f"El rango intercuartil para {element} es {IQR}")

    # Se establecen los límites para encontrar a los outliers.
    inferior = Q1 - 1.5 * IQR
    superior = Q3 + 1.5 * IQR

    # Filtrado de outliers
    outliers = data_b1[
        (data_b1[element] < inferior) | (data_b1[element] > superior)
    ]

    # Se observan los casos de outliers
    print(f"Se identificaron {outliers.shape[0]} outliers para {element}")
    print(outliers.head)
    print("\n")

# Se describe la composición de las variables categóricas del dataset. 

categóricas = ["payment_type" # tipo de pago
     ,"customer_age" # edad del cliente
     ,"employment_status"# estado de empleabilidad
     ,"housing_status" # estado de vivienda actual
     ,"has_other_cards" # ¿tiene otras tarjetas?
     ,"source" # origen de la transacción
     ,"device_os" # tipo de sistema operativo
     ,"fraud_bool" # Aplicación fraudulenta
     ]

print("\n\n")
print("Composición variables categóricas")

for element in categóricas: 
    print(element)
    print(data_b1[element].value_counts(normalize=True))
    print("\n")

# Entradas por método de pago.

sns.histplot(data_b1,x = "payment_type")
plt.xlabel("Tipo de pago")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de pago")
plt.show()

# Entradas por rango etario.

sns.histplot(data_b1,x = "customer_age")
plt.xlabel("Rango etario")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por rango etario")
plt.show()

# Entradas por estado de empleabilidad.

sns.histplot(data_b1,x = "employment_status")
plt.xlabel("Estado empleabilidad")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de empleabilidad")
plt.show()

# Entradas por estado de vivienda.

sns.histplot(data_b1,x = "housing_status")
plt.xlabel("Estado de vivienda")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de vivienda")
plt.show()

# Entradas por posesión de tarjetas.

data_counts = data_b1['has_other_cards'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por posesión de tarjetas")
plt.show()

# Entradas por origen de la transacción.

sns.histplot(data_b1,x = "source")
plt.xlabel("Origen")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por origen")
plt.show()

# Entradas por tipo de sistema operativo.

sns.histplot(data_b1,x = "device_os")
plt.xlabel("Tipo de sistema operativo")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de sistema operativo")
plt.show()

# Entradas por determinación de Aplicación fraudulenta.

data_counts = data_b1['fraud_bool'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por determinación de Aplicación fraudulenta")
plt.show()
# Out:
# Información del dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
# ...

# %% [markdown]
# ### Dataset 2

# %%
# Se observa la información del dataset.
print("Información del dataset")
print(data_b2.info())

print("\n\n")

# Se revisan si existen filas duplicadas.
duplicados = data_b2.duplicated()
print("Duplicados")
print(data_b2[duplicados])

# Se describe la composición de las variables numéricas del dataset
print("\n\n")
print("Composición variables numéricas")
print(data_b2.describe())

# Se revisan outliers para las variables numéricas. 

numericas = ["prev_address_months_count", "current_address_months_count", "intended_balcon_amount", "bank_months_count",
    "session_length_in_minutes", "device_distinct_emails_8w", "zip_count_4w", "velocity_6h", 
    "velocity_24h", "velocity_4w", "bank_branch_count_8w", "date_of_birth_distinct_emails_4w",
    "credit_risk_score", "income"
]

print("\n\n")
print("Outliers")
for element in numericas: 
    print(f"Proceso para {element}")
    # Se calcula el Q1 (Primer cuartil) y Q3 (Tercer cuartil).
    Q1 = data_b2[element].quantile(0.25)
    Q3 = data_b2[element].quantile(0.75)

    print(f"El primer cuartil para {element} es {Q1}")
    print(f"El tercer cuartil para {element} es {Q3}")

    # Se hace el cálculo del IQR (Rango Intercuartil).
    IQR = Q3 - Q1
    print(f"El rango intercuartil para {element} es {IQR}")

    # Se establecen los límites para encontrar a los outliers.
    inferior = Q1 - 1.5 * IQR
    superior = Q3 + 1.5 * IQR

    # Filtrado de outliers
    outliers = data_b2[
        (data_b2[element] < inferior) | (data_b2[element] > superior)
    ]

    # Se observan los casos de outliers
    print(f"Se identificaron {outliers.shape[0]} outliers para {element}")
    print(outliers.head)
    print("\n")

# Se describe la composición de las variables categóricas del dataset. 

categóricas = ["payment_type" # tipo de pago
     ,"customer_age" # edad del cliente
     ,"employment_status"# estado de empleabilidad
     ,"housing_status" # estado de vivienda actual
     ,"has_other_cards" # ¿tiene otras tarjetas?
     ,"source" # origen de la transacción
     ,"device_os" # tipo de sistema operativo
     ,"fraud_bool" # Aplicación fraudulenta
     ]

print("\n\n")
print("Composición variables categóricas")

for element in categóricas: 
    print(element)
    print(data_b2[element].value_counts(normalize=True))
    print("\n")

# Entradas por método de pago.

sns.histplot(data_b2,x = "payment_type")
plt.xlabel("Tipo de pago")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de pago")
plt.show()

# Entradas por rango etario.

sns.histplot(data_b2,x = "customer_age")
plt.xlabel("Rango etario")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por rango etario")
plt.show()

# Entradas por estado de empleabilidad.

sns.histplot(data_b2,x = "employment_status")
plt.xlabel("Estado empleabilidad")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de empleabilidad")
plt.show()

# Entradas por estado de vivienda.

sns.histplot(data_b2,x = "housing_status")
plt.xlabel("Estado de vivienda")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de vivienda")
plt.show()

# Entradas por posesión de tarjetas.

data_counts = data_b2['has_other_cards'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por posesión de tarjetas")
plt.show()

# Entradas por origen de la transacción.

sns.histplot(data_b2,x = "source")
plt.xlabel("Origen")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por origen")
plt.show()

# Entradas por tipo de sistema operativo.

sns.histplot(data_b2,x = "device_os")
plt.xlabel("Tipo de sistema operativo")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de sistema operativo")
plt.show()

# Entradas por determinación de Aplicación fraudulenta.

data_counts = data_b2['fraud_bool'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por determinación de Aplicación fraudulenta")
plt.show()
# Out:
# Información del dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
# ...

# %% [markdown]
# ### Dataset 3

# %%
# Se observa la información del dataset.
print("Información del dataset")
print(data_b3.info())

print("\n\n")

# Se revisan si existen filas duplicadas.
duplicados = data_b3.duplicated()
print("Duplicados")
print(data_b3[duplicados])

# Se describe la composición de las variables numéricas del dataset
print("\n\n")
print("Composición variables numéricas")
print(data_b3.describe())

# Se revisan outliers para las variables numéricas. 

numericas = ["prev_address_months_count", "current_address_months_count", "intended_balcon_amount", "bank_months_count",
    "session_length_in_minutes", "device_distinct_emails_8w", "zip_count_4w", "velocity_6h", 
    "velocity_24h", "velocity_4w", "bank_branch_count_8w", "date_of_birth_distinct_emails_4w",
    "credit_risk_score", "income"
]

print("\n\n")
print("Outliers")
for element in numericas: 
    print(f"Proceso para {element}")
    # Se calcula el Q1 (Primer cuartil) y Q3 (Tercer cuartil).
    Q1 = data_b3[element].quantile(0.25)
    Q3 = data_b3[element].quantile(0.75)

    print(f"El primer cuartil para {element} es {Q1}")
    print(f"El tercer cuartil para {element} es {Q3}")

    # Se hace el cálculo del IQR (Rango Intercuartil).
    IQR = Q3 - Q1
    print(f"El rango intercuartil para {element} es {IQR}")

    # Se establecen los límites para encontrar a los outliers.
    inferior = Q1 - 1.5 * IQR
    superior = Q3 + 1.5 * IQR

    # Filtrado de outliers
    outliers = data_b3[
        (data_b3[element] < inferior) | (data_b3[element] > superior)
    ]

    # Se observan los casos de outliers
    print(f"Se identificaron {outliers.shape[0]} outliers para {element}")
    print(outliers.head)
    print("\n")

# Se describe la composición de las variables categóricas del dataset. 

categóricas = ["payment_type" # tipo de pago
     ,"customer_age" # edad del cliente
     ,"employment_status"# estado de empleabilidad
     ,"housing_status" # estado de vivienda actual
     ,"has_other_cards" # ¿tiene otras tarjetas?
     ,"source" # origen de la transacción
     ,"device_os" # tipo de sistema operativo
     ,"fraud_bool" # Aplicación fraudulenta
     ]

print("\n\n")
print("Composición variables categóricas")

for element in categóricas: 
    print(element)
    print(data_b3[element].value_counts(normalize=True))
    print("\n")

# Entradas por método de pago.

sns.histplot(data_b3,x = "payment_type")
plt.xlabel("Tipo de pago")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de pago")
plt.show()

# Entradas por rango etario.

sns.histplot(data_b3,x = "customer_age")
plt.xlabel("Rango etario")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por rango etario")
plt.show()

# Entradas por estado de empleabilidad.

sns.histplot(data_b3,x = "employment_status")
plt.xlabel("Estado empleabilidad")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de empleabilidad")
plt.show()

# Entradas por estado de vivienda.

sns.histplot(data_b3,x = "housing_status")
plt.xlabel("Estado de vivienda")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de vivienda")
plt.show()

# Entradas por posesión de tarjetas.

data_counts = data_b3['has_other_cards'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por posesión de tarjetas")
plt.show()

# Entradas por origen de la transacción.

sns.histplot(data_b3,x = "source")
plt.xlabel("Origen")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por origen")
plt.show()

# Entradas por tipo de sistema operativo.

sns.histplot(data_b3,x = "device_os")
plt.xlabel("Tipo de sistema operativo")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de sistema operativo")
plt.show()

# Entradas por determinación de Aplicación fraudulenta.

data_counts = data_b3['fraud_bool'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por determinación de Aplicación fraudulenta")
plt.show()
# Out:
# Información del dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
# ...

# %% [markdown]
# ### Dataset 4

# %%
# Se observa la información del dataset.
print("Información del dataset")
print(data_b4.info())

print("\n\n")

# Se revisan si existen filas duplicadas.
duplicados = data_b4.duplicated()
print("Duplicados")
print(data_b4[duplicados])

# Se describe la composición de las variables numéricas del dataset
print("\n\n")
print("Composición variables numéricas")
print(data_b4.describe())

# Se revisan outliers para las variables numéricas. 

numericas = ["prev_address_months_count", "current_address_months_count", "intended_balcon_amount", "bank_months_count",
    "session_length_in_minutes", "device_distinct_emails_8w", "zip_count_4w", "velocity_6h", 
    "velocity_24h", "velocity_4w", "bank_branch_count_8w", "date_of_birth_distinct_emails_4w",
    "credit_risk_score", "income"
]

print("\n\n")
print("Outliers")
for element in numericas: 
    print(f"Proceso para {element}")
    # Se calcula el Q1 (Primer cuartil) y Q3 (Tercer cuartil).
    Q1 = data_b4[element].quantile(0.25)
    Q3 = data_b4[element].quantile(0.75)

    print(f"El primer cuartil para {element} es {Q1}")
    print(f"El tercer cuartil para {element} es {Q3}")

    # Se hace el cálculo del IQR (Rango Intercuartil).
    IQR = Q3 - Q1
    print(f"El rango intercuartil para {element} es {IQR}")

    # Se establecen los límites para encontrar a los outliers.
    inferior = Q1 - 1.5 * IQR
    superior = Q3 + 1.5 * IQR

    # Filtrado de outliers
    outliers = data_b4[
        (data_b4[element] < inferior) | (data_b4[element] > superior)
    ]

    # Se observan los casos de outliers
    print(f"Se identificaron {outliers.shape[0]} outliers para {element}")
    print(outliers.head)
    print("\n")

# Se describe la composición de las variables categóricas del dataset. 

categóricas = ["payment_type" # tipo de pago
     ,"customer_age" # edad del cliente
     ,"employment_status"# estado de empleabilidad
     ,"housing_status" # estado de vivienda actual
     ,"has_other_cards" # ¿tiene otras tarjetas?
     ,"source" # origen de la transacción
     ,"device_os" # tipo de sistema operativo
     ,"fraud_bool" # Aplicación fraudulenta
     ]

print("\n\n")
print("Composición variables categóricas")

for element in categóricas: 
    print(element)
    print(data_b4[element].value_counts(normalize=True))
    print("\n")

# Entradas por método de pago.

sns.histplot(data_b4,x = "payment_type")
plt.xlabel("Tipo de pago")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de pago")
plt.show()

# Entradas por rango etario.

sns.histplot(data_b4,x = "customer_age")
plt.xlabel("Rango etario")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por rango etario")
plt.show()

# Entradas por estado de empleabilidad.

sns.histplot(data_b4,x = "employment_status")
plt.xlabel("Estado empleabilidad")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de empleabilidad")
plt.show()

# Entradas por estado de vivienda.

sns.histplot(data_b4,x = "housing_status")
plt.xlabel("Estado de vivienda")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de vivienda")
plt.show()

# Entradas por posesión de tarjetas.

data_counts = data_b4['has_other_cards'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por posesión de tarjetas")
plt.show()

# Entradas por origen de la transacción.

sns.histplot(data_b4,x = "source")
plt.xlabel("Origen")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por origen")
plt.show()

# Entradas por tipo de sistema operativo.

sns.histplot(data_b4,x = "device_os")
plt.xlabel("Tipo de sistema operativo")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de sistema operativo")
plt.show()

# Entradas por determinación de Aplicación fraudulenta.

data_counts = data_b4['fraud_bool'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por determinación de Aplicación fraudulenta")
plt.show()
# Out:
# Información del dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
# ...

# %% [markdown]
# ### Dataset 5

# %%
# Se observa la información del dataset.
print("Información del dataset")
print(data_b5.info())

print("\n\n")

# Se revisan si existen filas duplicadas.
duplicados = data_b5.duplicated()
print("Duplicados")
print(data_b5[duplicados])

# Se describe la composición de las variables numéricas del dataset
print("\n\n")
print("Composición variables numéricas")
print(data_b5.describe())

# Se revisan outliers para las variables numéricas. 

numericas = ["prev_address_months_count", "current_address_months_count", "intended_balcon_amount", "bank_months_count",
    "session_length_in_minutes", "device_distinct_emails_8w", "zip_count_4w", "velocity_6h", 
    "velocity_24h", "velocity_4w", "bank_branch_count_8w", "date_of_birth_distinct_emails_4w",
    "credit_risk_score", "income"
]

print("\n\n")
print("Outliers")
for element in numericas: 
    print(f"Proceso para {element}")
    # Se calcula el Q1 (Primer cuartil) y Q3 (Tercer cuartil).
    Q1 = data_b5[element].quantile(0.25)
    Q3 = data_b5[element].quantile(0.75)

    print(f"El primer cuartil para {element} es {Q1}")
    print(f"El tercer cuartil para {element} es {Q3}")

    # Se hace el cálculo del IQR (Rango Intercuartil).
    IQR = Q3 - Q1
    print(f"El rango intercuartil para {element} es {IQR}")

    # Se establecen los límites para encontrar a los outliers.
    inferior = Q1 - 1.5 * IQR
    superior = Q3 + 1.5 * IQR

    # Filtrado de outliers
    outliers = data_b5[
        (data_b5[element] < inferior) | (data_b5[element] > superior)
    ]

    # Se observan los casos de outliers
    print(f"Se identificaron {outliers.shape[0]} outliers para {element}")
    print(outliers.head)
    print("\n")

# Se describe la composición de las variables categóricas del dataset. 

categóricas = ["payment_type" # tipo de pago
     ,"customer_age" # edad del cliente
     ,"employment_status"# estado de empleabilidad
     ,"housing_status" # estado de vivienda actual
     ,"has_other_cards" # ¿tiene otras tarjetas?
     ,"source" # origen de la transacción
     ,"device_os" # tipo de sistema operativo
     ,"fraud_bool" # Aplicación fraudulenta
     ]

print("\n\n")
print("Composición variables categóricas")

for element in categóricas: 
    print(element)
    print(data_b5[element].value_counts(normalize=True))
    print("\n")

# Entradas por método de pago.

sns.histplot(data_b5,x = "payment_type")
plt.xlabel("Tipo de pago")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de pago")
plt.show()

# Entradas por rango etario.

sns.histplot(data_b5,x = "customer_age")
plt.xlabel("Rango etario")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por rango etario")
plt.show()

# Entradas por estado de empleabilidad.

sns.histplot(data_b5,x = "employment_status")
plt.xlabel("Estado empleabilidad")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de empleabilidad")
plt.show()

# Entradas por estado de vivienda.

sns.histplot(data_b5,x = "housing_status")
plt.xlabel("Estado de vivienda")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por estado de vivienda")
plt.show()

# Entradas por posesión de tarjetas.

data_counts = data_b5['has_other_cards'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por posesión de tarjetas")
plt.show()

# Entradas por origen de la transacción.

sns.histplot(data_b5,x = "source")
plt.xlabel("Origen")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por origen")
plt.show()

# Entradas por tipo de sistema operativo.

sns.histplot(data_b5,x = "device_os")
plt.xlabel("Tipo de sistema operativo")
plt.ylabel("Total de entradas")
plt.title("Número de entradas por tipo de sistema operativo")
plt.show()

# Entradas por determinación de Aplicación fraudulenta.

data_counts = data_b5['fraud_bool'].value_counts()
plt.pie(data_counts,labels=data_counts.index,autopct='%1.1f%%')
plt.title("Número de entradas por determinación de Aplicación fraudulenta")
plt.show()
# Out:
# Información del dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
# ...

# %% [markdown]
# ## Unificación de entradas identificadas como fraudulentas

# %%
# Se filtran los datasets para contar únicamente con las filas donde 'fraud_bool' es 1
data_base_filtered = data_base[data_base['fraud_bool'] == 1]
data_b1_filtered = data_b1[data_b1['fraud_bool'] == 1]
data_b2_filtered = data_b2[data_b2['fraud_bool'] == 1]
data_b3_filtered = data_b3[data_b3['fraud_bool'] == 1]
data_b4_filtered = data_b4[data_b4['fraud_bool'] == 1]
data_b5_filtered = data_b5[data_b5['fraud_bool'] == 1]

# Unimos todos los datasets y agregamos una clave para identificar el origen
datasets_fraudes = pd.concat([data_base_filtered, data_b1_filtered, data_b2_filtered, data_b3_filtered, data_b4_filtered, data_b5_filtered],
                            keys=['data_base', 'data_b1', 'data_b2', 'data_b3', 'data_b4', 'data_b5'],  # Etiquetas para cada dataset
                            names=['Dataset_Origen'])  # Nombre del índice

# Reseteamos el índice para que la clave (origen del DataFrame) se convierta en una columna
datasets_fraudes = datasets_fraudes.reset_index(level='Dataset_Origen')

# Mostrar los primeros datos unidos con la columna que indica el origen
datasets_fraudes.sample(10)
# Out:
#        Dataset_Origen  fraud_bool  income  name_email_similarity  \
# 836095        data_b4           1     0.9               0.826253
# 74757         data_b1           1     0.9               0.863153
# 885480        data_b2           1     0.8               0.919485
# 775831        data_b2           1     0.9               0.023328
# 898944      data_base           1     0.5               0.086234
# 387573        data_b1           1     0.1               0.880602
# 599640        data_b4           1     0.5               0.046363
# 565521        data_b3           1     0.9               0.061452
# 113902        data_b4           1     0.7               0.889818
# 930812        data_b3           1     0.9               0.431452
#
#         prev_address_months_count  current_address_months_count  customer_age  \
# 836095                         -1                           124            50
# 74757                          -1                            14            40
# ...

# %%
# Reemplazamos los valores menores a 0 por None en las columnas donde es requerido: 

columnas = ["prev_address_months_count","current_address_months_count","intended_balcon_amount","bank_months_count","session_length_in_minutes","device_distinct_emails_8w"]

for columna in columnas:
    datasets_fraudes[columna] = datasets_fraudes[columna].apply(lambda x: None if x < 0 else x)

# %%
# Se eliminan columnas innecesarias
datasets_fraudes_limpio= datasets_fraudes.drop(columns=["month","x1","x2"])

# %%
datasets_fraudes_limpio.sample(5)
# Out:
#        Dataset_Origen  fraud_bool  income  name_email_similarity  \
# 559825        data_b2           1     0.8               0.095449
# 758183        data_b5           1     0.8               0.993944
# 613594        data_b4           1     0.5               0.247430
# 885225        data_b1           1     0.8               0.805773
# 323797        data_b1           1     0.8               0.104341
#
#         prev_address_months_count  current_address_months_count  customer_age  \
# 559825                        NaN                         119.0            50
# 758183                        NaN                         174.0            70
# 613594                        NaN                          89.0            70
# 885225                        NaN                         295.0            50
# 323797                        NaN                          93.0            20
#
#         days_since_request  intended_balcon_amount payment_type  zip_count_4w  \
# ...

# %%
datasets_fraudes_limpio.shape[0]
# Out:
# 66177

# %%
# Se guarda el dataset de fraudes en un archivo aparte para utilización posterior. 

datasets_fraudes_limpio.to_parquet("../../dashboard/Df_fraudes.parquet")

# %%
# Se revisa que el archivo cargue correctamente. 
fraudes = pd.read_parquet("../../dashboard/Df_fraudes.parquet")
fraudes.sample(10)
# Out:
#        Dataset_Origen  fraud_bool  income  name_email_similarity  \
# 486150        data_b5           1     0.2               0.349438
# 488241        data_b5           1     0.9               0.350885
# 91653         data_b5           1     0.9               0.196597
# 815230        data_b1           1     0.8               0.219674
# 74214         data_b5           1     0.9               0.722280
# 503611        data_b2           1     0.9               0.298581
# 524483        data_b2           1     0.2               0.151803
# 453789        data_b4           1     0.8               0.910390
# 54478       data_base           1     0.8               0.502248
# 820416      data_base           1     0.9               0.484958
#
#         prev_address_months_count  current_address_months_count  customer_age  \
# 486150                        NaN                          97.0            60
# 488241                        NaN                          98.0            50
# ...

# %%
fraudes.describe()
# Out:
#        fraud_bool        income  name_email_similarity  \
# count     66177.0  66177.000000           66177.000000
# mean          1.0      0.689436               0.399415
# std           0.0      0.264922               0.298138
# min           1.0      0.100000               0.000091
# 25%           1.0      0.600000               0.135011
# 50%           1.0      0.800000               0.298523
# 75%           1.0      0.900000               0.684215
# max           1.0      0.900000               0.999996
#
#        prev_address_months_count  current_address_months_count  customer_age  \
# count                4968.000000                  66114.000000  66177.000000
# mean                   87.809984                    119.882188     43.916466
# std                    83.607304                     87.579541     13.256218
# min                     8.000000                      0.000000     10.000000
# 25%                    28.000000                     56.000000     30.000000
# ...

# %%
# Se establecen los puntos de corte a utilizar posteriormente en el dashboard con el propósito de ayudar a visualizar algunas de las variables numéricas.

# Income, proposed_credit_limit

columnas = ["income","proposed_credit_limit","name_email_similarity","credit_risk_score","intended_balcon_amount"]

for element in columnas:
    num_partes = 3
    puntos_de_corte = np.linspace(fraudes[element].min(), fraudes[element].max(), num_partes + 1)[1:-1]

    print(f"Los puntos de corte para {element} son:", puntos_de_corte)
# Out:
# Los puntos de corte para income son: [0.36666667 0.63333333]
# Los puntos de corte para proposed_credit_limit son: [ 826.66666667 1463.33333333]
# Los puntos de corte para name_email_similarity son: [0.33339303 0.66669465]
# Los puntos de corte para credit_risk_score son: [ 42. 210.]
# Los puntos de corte para intended_balcon_amount son: [37.17204086 74.34402081]
